# %% [markdown]
# ### Create a medical terms dictionary from https://www.medicinenet.com/

# %%
# %pip install selenium
# %pip install tqdm

# %% [markdown]
# #### Import necessary libraries

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import re
from tqdm import tqdm
from selenium.common.exceptions import TimeoutException

from textblob import TextBlob
from autocorrect import Speller

width = 1440
height = 990

# %%
import nltk
from nltk.corpus import wordnet

# %% [markdown]
# #### Open Chrome Web browser

# %%
options = webdriver.ChromeOptions()
driver = webdriver.Chrome(options=options)

# %% [markdown]
# #### Web scrap medical terms to make glossary

# %%
base_url = 'https://www.medicinenet.com/script/main/alphaidx.asp?p='
alphabets = 'abcdefghijklmnopqrstuvwxyz'
med_words = {}

for letter in tqdm(alphabets):
    curr_url=base_url+letter+"_dict"
    med_words[letter] = []
    
    driver.set_page_load_timeout(10)
    try:
        driver.get(curr_url)
    except TimeoutException:
        driver.execute_script("window.stop();")
        
    elements = driver.find_elements(By.XPATH,'//div[@class="AZ_results"]/ul/li/a')
    for element in elements:
        med_words[letter].append(element.text)

driver.quit()
# Out:
#   0%|          | 0/26 [00:00<?, ?it/s]
# 100%|██████████| 26/26 [03:29<00:00,  8.05s/it]

# %%
sum(len(med_words[letter]) for letter in med_words)
# Out:
# 4205

# %%
med_words['a']
# Out:
# ['A (adenine)',
#  'A-',
#  'A-T',
#  'a.c.',
#  'AAA',
#  'AAAS',
#  'AAD',
#  'AAO',
#  'AAP',
#  'Aarskog syndrome',
#  'Aarskog-Scott syndrome',
#  'Aase-Smith syndrome I',
#  'Aase-Smith syndrome II',
#  'Ab-',
#  'Abate',
#  'Abatement',
#  'Abdomen',
#  'Abdomen, acute',
#  'Abdominal',
#  'Abdominal aorta',
#  'Abdominal aortic aneurysm',
#  'Abdominal cavity',
#  'Abdominal guarding',
#  'Abdominal hysterectomy',
#  'Abdominal pain',
#  'Abducent nerve',
#  'Abduction',
#  'Abductor muscle',
#  'Aberration',
#  'Abiotic',
#  'Abiotrophy',
#  'Ablate',
#  'Ablation',
#  'Abnormal',
#  'Abortifacient',
#  'Abortion',
#  'Abortive',
#  'Abortive polio',
#  'ABR test',
#  'Abrade',
#  'Abrasion',
#  'Abs',
#  'Abscess',
#  'Abscission',
#  'Abse',
#  'Absence of the breast',
#  'Absence of the nipple',
#  'Absence seizure',
#  'Absent eye',
#  'Absinthism',
#  'Absolute neutrophil count',
#  'Absorb',
#  'Absorption',
#  'Abstinence',
#  'AC joint',
#  'Acanthamoeba',
#  'Acapnia',
#  'Acaricide',
#  'ACC',
#  'Access',
#  'Accessory',
#  'Accessory digestive organ',
#  'Accessory dwelling unit',
#  'Accessory placenta',
#  'Accommodation',
#  'Acellular',
#  'Acentric chromosome',
#  'Acetabulum',
#  'Acetaminophen',
#  'Acetate',
#  'Acetone',
#  'Acetylcholine',
#  'Acetylcysteine',
#  'ACh (acetylcholine)',
#  'Achalasia',
#  'AChE (acetylcholinesterase)',
#  'Achilles tendon',
#  'Achillobursitis',
#  'Achoo syndrome',
#  'Acid indigestion',
#  'Acid phosphatase',
#  'Acid-base balance',
#  'Acidophilus',
#  'Acidosis',
#  'Acinus, pulmonary',
#  'Acne',
#  'Acne vulgaris',
#  'Acou-',
#  'Acoustic',
#  'Acquired',
#  'Acquired immunity',
#  'Acrocentric chromosome',
#  'Acrochordon',
#  'Acrocyanosis',
#  'Acrodynia',
#  'Acromegaly',
#  'Acromion',
#  'Acrophobia',
#  'Actinic',
#  'Actinic keratosis',
#  'Acu-',
#  'Acupressure',
#  'Acute',
#  'Acute abdomen',
#  'Acute bronchitis',
#  'Acute glomerulonephritis',
#  'Acute idiopathic polyneuritis',
#  'Acute illness',
#  'Acute mountain sickness (AMS)',
#  'Acute myocardial infarction',
#  'Acute nonlymphocytic leukemia',
#  'Acute otitis media',
#  'Acute pain',
#  'Acute pancreatitis',
#  'Acute promyelocytic leukemia',
#  'Acute renal failure',
#  'Acute stress disorder',
#  'Acute thrombocytopenic purpura',
#  'Acyclovir',
#  'Ad lib',
#  'Ad-',
#  'ADA deficiency',
#  "Adam's apple",
#  'Adamantine',
#  'ADCC (antibody-dependent cell-mediated cytotox.)',
#  'ADD (attention deficit disorder)',
#  'Addiction',
#  'Addison anemia',
#  'Addison disease',
#  'Addisonian anemia',
#  'Additive genetic effects',
#  'Adduction',
#  'Adductor muscle',
#  'Aden-',
#  'Adenitis',
#  'Adeno-',
#  'Adenocarcinoma',
#  'Adenoiditis',
#  'Adenoids',
#  'Adenoma',
#  'Adenopathy',
#  'Adenosine',
#  'Adenosine deaminase (ADA) deficiency',
#  'Adenosine triphosphate',
#  'ADHD (Attention deficit hyperactivity disorder)',
#  'Adhesion',
#  'ADI',
#  'Adipocyte',
#  'Adipose',
#  'Adiposity',
#  'Adjacent',
#  'Adjuvant',
#  'Adjuvant therapy',
#  'ADLs (activities of daily living)',
#  'Admission',
#  'Adnexa',
#  'Adrenal cortex',
#  'Adrenal failure',
#  'Adrenal gland',
#  'Adrenal medulla',
#  'Adrenaline',
#  'Adrenoleukodystrophy',
#  'ADU',
#  'Adult primary liver cancer',
#  'Advance directives',
#  'Adventitious',
#  'Adverse effect',
#  'Adverse reaction',
#  'Aer-, aero-',
#  'Aerobic',
#  'Aerobic exercise',
#  'Aerophagia',
#  'Aerophobia',
#  'Aerosol',
#  'Aerotitis',
#  'Aesculapius',
#  'Aetiology',
#  'Affect',
#  'Afferent',
#  'Affinity',
#  'AFIP',
#  'AFO (ankle-foot orthosis)',
#  'Afterbirth',
#  'Age by decade',
#  'Age-Related Macular Degeneration',
#  'Agent, tocolytic',
#  'Ageusia',
#  'Aggressive',
#  'Aging',
#  'Agita',
#  'Agonist',
#  'Agoraphobia',
#  'Agranulocytosis',
#  'Ague',
#  'Agyrophobia',
#  'AHD',
#  'AID (artificial insemination by donor)',
#  'AIDS',
#  'AIDS-related complex',
#  'AIH (artificial insemination by husband)',
#  'Air bag',
#  'Air-conditioner lung',
#  'Airway',
#  'AK',
#  'AKA (above the knee amputation)',
#  'Akathisia',
#  'Akinesia',
#  'Akinetic',
#  'ALA',
#  'Alanine',
#  'Alanine aminotransferase (ALT)',
#  'Alb-',
#  'Albinism',
#  'Albinism, oculocutaneous',
#  'Albino',
#  'Albumen',
#  'Albumin',
#  'Albuminuria',
#  'Alcohol',
#  'Alcohol poisoning',
#  'Alcoholism',
#  'Aldosterone',
#  'Alembic',
#  'Alexia',
#  'algia',
#  'Alimentary',
#  'Alkaline phosphatase',
#  'Alkaloid',
#  'Alkalosis',
#  'Allelic',
#  'Allergic contact dermatitis',
#  'Allergic reaction',
#  'Allergic rhinitis',
#  'Allergy',
#  'Allogeneic',
#  'Allograft',
#  'Allopathic medicine',
#  'Allopathy',
#  'Alongshan Virus (ALSV)',
#  'Alopecia',
#  'Alopecia areata',
#  'Alprazolam',
#  'ALT (alanine aminotransferase)',
#  'Alternative medicine',
#  'Altitude sickness',
#  'Alveolar',
#  'Alveolar hydatid disease',
#  'Alveoli',
#  'Alveolitis',
#  "Alzheimer's disease",
#  'Amastia',
#  'Amathophobia',
#  'Ambidextrous',
#  'Ambient',
#  'Ambiguous genitalia',
#  'Amblyopia',
#  'AMC (arthrogryposis multiplex congenita)',
#  'Amebiasis',
#  'Amelioration',
#  'Amenia',
#  'Amenorrhea',
#  'American Academy of Pediatrics',
#  'American Dental Association (ADA)',
#  'AMI',
#  'Amino acid',
#  'Amino acid symbols',
#  'Amino acids',
#  'Aminotransferase',
#  'Amitriptyline',
#  'AML',
#  'Ammonia',
#  'Amnesia',
#  'Amnion',
#  'Amok',
#  'Amphetamine',
#  'Ampulla',
#  'Amputation',
#  'Amsler grid',
#  'Amusia',
#  'Amygdala',
#  'Amygdaloid nucleus',
#  'Amyl-',
#  'Amylase',
#  'Amylo-',
#  'Amyloidosis',
#  'An-',
#  'ANA',
#  'Anaerobic',
#  'Anaesthesia',
#  'Anal fistula',
#  'Anal papilla',
#  'Anal papillae',
#  'Analgesia',
#  'Analgesic',
#  'Analog',
#  'Analogous',
#  'Analysis',
#  'Anaphia',
#  'Anaphylactic shock',
#  'Anaphylactoid purpura',
#  'Anaphylaxis',
#  'Anaptic',
#  'Anasarca',
#  'Anastrozole',
#  'Anatomic orientation terms',
#  'Anatomical position',
#  'Anatomy',
#  'Anatomy, gross',
#  'ANC',
#  'Androgen',
#  'Androgenic',
#  'Android pelvis',
#  'Anemia',
#  'Anemic',
#  'Anesthesia',
#  'Anesthetic',
#  'Aneurysm',
#  'Angelman syndrome',
#  'Anger',
#  'Angiitis',
#  'Angina',
#  'Angina pectoris',
#  'Angioedema',
#  'Angiogenesis',
#  'Angiogram',
#  'Angiography',
#  'Angiomyolipoma',
#  'Angioneurotic edema, hereditary',
#  'Angiopathy',
#  'Angioplasty',
#  'Angiotensin',
#  'Angiotensin converting enzyme',
#  'Angiotensin receptor blocker',
#  'Angle-closure glaucoma',
#  'Anhedonia',
#  'Anion',
#  'Anion gap',
#  'Aniso-',
#  'Anisometropia',
#  'Ankle',
#  'Ankle bone',
#  'Ankle-foot orthosis',
#  'Ankyloglossia',
#  'Ankylose',
#  'Ankylosing',
#  'Ankylosing spondylitis',
#  'Ankylosis',
#  'Annulus',
#  'Anogenital tract',
#  'Anomaly',
#  'Anomia',
#  'Anorexia',
#  'Anorgasmy',
#  'Anoxia',
#  'Antagonist',
#  'Antegrade',
#  'Anterior',
#  'Anterior chamber',
#  'Anterior cruciate ligament',
#  'Antero-',
#  'Anterolisthesis',
#  'Anteroposterior',
#  'Anteroposterior (AP)',
#  'Anthrax',
#  'Anti-',
#  'Anti-infective',
#  'Antibacterial',
#  'Antibiotic',
#  'Antibody',
#  'Anticholinergic',
#  'Anticoagulant',
#  'Anticoagulant agent',
#  'Anticonvulsant',
#  'Antidepressant',
#  'Antidepressants',
#  'Antidiabetic agent',
#  'Antidiuretic hormone (ADH)',
#  'Antidote',
#  'Antiemetics',
#  'Antiestrogen',
#  'Antifungal',
#  'Antifungal agent',
#  'Antifungal medication',
#  'Antigen',
#  'Antihistamines',
#  'Antihypertensive',
#  'Antimalarial',
#  'Antimetabolite',
#  'Antimicrobial',
#  'Antimicrobial agent',
#  'Antimicrobial drug',
#  'Antimony',
#  'Antineoplastic',
#  'Antioxidant',
#  'Antiprotozoal',
#  'Antiprotozoal drug',
#  'Antipsychotic',
#  'Antipyretic',
#  'Antiretroviral',
#  'Antisepsis',
#  'Antiseptic',
#  'Antispasmodic',
#  'Antithyroid drug',
#  'Antitoxin',
#  'Antiviral',
#  'Antrum',
#  'Anus',
#  'Anxiety',
#  'Anxiety disorder',
#  'AOA',
#  'Aorta',
#  'Aortal',
#  'Aortic',
#  'Aortic aneurysm',
#  'Aortic arch',
#  'Aortic regurgitation',
#  'Aortic stenosis',
#  'Aortic valve',
#  'Aortitis',
#  'AP',
#  'AP, X-ray',
#  'APA',
#  'APC',
#  'APC (immunology)',
#  'APC (medication)',
#  'APECED (autoimmune polyendocrinopathy)',
#  'Apex',
#  'Aphagia',
#  'Apheresis',
#  'Aphrasia',
#  'Apical',
#  'Aplastic anemia',
#  'APLS (antiphospholipid antibody syndrome)',
#  'Apnea',
#  'Apneic',
#  'Apophenia',
#  'Apoplexy',
#  'Apoptosis',
#  'Appendectomy',
#  'Appendiceal',
#  'Appendiceal cancer',
#  'Appendiceal rupture',
#  'Appendicitis',
#  'Appendix',
#  'Appendix cancer',
#  'Apposition',
#  'APS (autoimmune polyglandular syndrome)',
#  'Aquaporin',
#  'Aqueous humor',
#  'ARD',
#  'Areola',
#  'Arimidex',
#  'Arm',
#  'Aromatase',
#  'Aromatase inhibitor',
#  'Aromatherapy',
#  'Arrector pili',
#  'Arrhythmia',
#  'Arsenic',
#  'ART (antiretroviral therapy)',
#  'Artemisinin',
#  'Arteria femoralis',
#  'Arterial blood gas (ABG)',
#  'Arterial tension',
#  'Arteriogram',
#  'Arteriole',
#  'Arteriosclerosis',
#  'Arteriosclerotic retinopathy',
#  'Arteriovenous malformation (AVM)',
#  'Artery',
#  'Arthralgia',
#  'Arthritis',
#  'Arthro-',
#  'Arthrocentesis',
#  'Arthrogram',
#  'Arthropathy',
#  'Arthrosis',
#  'Articulation',
#  'Artificial abortion',
#  'Artificial insemination by husband (AIH)',
#  'ASA (drug caution code)',
#  'Ascites',
#  'Ascorbic acid',
#  'Ascus',
#  'Aseptic',
#  'ASL',
#  'ASOT',
#  'Asp',
#  'Aspartame',
#  'Aspartate aminotransferase (AST)',
#  'Aspartic acid',
#  'Asperger syndrome',
#  'Asphyxia',
#  'Aspirate',
#  'Aspiration',
#  'Aspirin',
#  'Assay',
#  'Association',
#  'Asthenia',
#  'Asthenic',
#  'Asthma',
#  'Asystole',
#  'Ataxia',
#  'Athelia',
#  'Atheroma',
#  'Atherosclerosis',
#  'Atherosclerotic',
#  "Athlete's foot",
#  'Atlas and axis joint',
#  'ATM',
#  'Atom',
#  'Atonic',
#  'Atopic',
#  'Atopic dermatitis',
#  'Atopy',
#  'ATP',
#  'Atresia',
#  'Atria',
#  'Atrial',
#  'Atrial fib',
#  'Atrial fibrillation',
#  'Atrial flutter',
#  'Atrial septum',
#  'Atrioventricular (AV)',
#  'Atrioventricular node',
#  'Atrium',
#  'Atrophy',
#  'Atropine',
#  'Attention',
#  'Attention deficit disorder (ADD)',
#  'Attention deficit hyperactivity disorder',
#  'Attenuated',
#  'Atypical',
#  'Atypical measles syndrome (AMS)',
#  'Auditory acuity',
#  'Auditory perception',
#  'Aura',
#  'Autism',
#  'Autistic savant',
#  'Autoimmune',
#  'Autoimmune disease',
#  'Autoimmunity',
#  'Autologous',
#  'Autolysis',
#  'Automated external defibrillator',
#  'Autonomic nervous system',
#  'Autonomy, patient',
#  'Autophobia',
#  'Autoradiography',
#  'Autosomal dominant',
#  'Autosomal recessive',
#  'AV (atrioventricular)',
#  'Avuncular',
#  'Axial tomography, computerized',
#  'Axillary',
#  'Ayurveda',
#  'Azotemia']

# %% [markdown]
# #### Copy the terms into file

# %%
file_path = 'med_terms.txt'
try:
    with open(file_path, 'r') as file:
        pass
except FileNotFoundError:
    with open(file_path, 'w') as file:
        for letter in med_words.values():
            for word in letter:
                file.write(word + '\n')

# %% [markdown]
# #### Implement spell check

# %% [markdown]
# Sample Usage

# %%
text = "Why can't yu spel corrctly?"
tb = TextBlob(text)
tb
# Out:
# TextBlob("Why can't yu spel corrctly?")

# %%
print(tb.correct())
# Out:
# Why can't you spell correctly?

# %%
txt = '''
1 yeas olf old i patent paseo ‘Vinee >

A reliable ioral; Sa at Chomapape

with the clu cowplaints Bn
ita . ‘ ~~ fog

tle ipsa ae pl se

Geen)

J2aes Sawiduews Ww onset Set | cal «
Dusation > aday of

p” OAV! Ay

Qi vamal vanation : ue |

No Aq4: oy S —_
Rokoving “ae wudieation: N 4
Jupe of five: High grade .
oneewa t
Nl ells & vig" :
IN

ee i 4
Auaation —Stne \d days |
i, ue k weak anoticed.
No expe to onlvonn Kamp

ie
No a Hficourt itand sid

Nofomieel Wee

————————————

Kc
\
\
'''

# %%
txt_words = re.findall(r'[a-zA-Z0-9]+', txt)
txt_words
# Out:
# ['1',
#  'yeas',
#  'olf',
#  'old',
#  'i',
#  'patent',
#  'paseo',
#  'Vinee',
#  'A',
#  'reliable',
#  'ioral',
#  'Sa',
#  'at',
#  'Chomapape',
#  'with',
#  'the',
#  'clu',
#  'cowplaints',
#  'Bn',
#  'ita',
#  'fog',
#  'tle',
#  'ipsa',
#  'ae',
#  'pl',
#  'se',
#  'Geen',
#  'J2aes',
#  'Sawiduews',
#  'Ww',
#  'onset',
#  'Set',
#  'cal',
#  'Dusation',
#  'aday',
#  'of',
#  'p',
#  'OAV',
#  'Ay',
#  'Qi',
#  'vamal',
#  'vanation',
#  'ue',
#  'No',
#  'Aq4',
#  'oy',
#  'S',
#  'Rokoving',
#  'ae',
#  'wudieation',
#  'N',
#  '4',
#  'Jupe',
#  'of',
#  'five',
#  'High',
#  'grade',
#  'oneewa',
#  't',
#  'Nl',
#  'ells',
#  'vig',
#  'IN',
#  'ee',
#  'i',
#  '4',
#  'Auaation',
#  'Stne',
#  'd',
#  'days',
#  'i',
#  'ue',
#  'k',
#  'weak',
#  'anoticed',
#  'No',
#  'expe',
#  'to',
#  'onlvonn',
#  'Kamp',
#  'ie',
#  'No',
#  'a',
#  'Hficourt',
#  'itand',
#  'sid',
#  'Nofomieel',
#  'Wee',
#  'Kc']

# %%
def editDistance(s,t):
    n = len(s)
    m = len(t)

    prev = [j for j in range(m+1)]
    curr = [0] * (m+1)

    for i in range(1, n+1):
        curr[0] = i
        for j in range(1, m+1):
            if s[i-1] == t[j-1]:
                curr[j] = prev[j-1]
            else:
                mn = min(1 + prev[j], 1 + curr[j-1])
                curr[j] = min(mn, 1 + prev[j-1])
        prev = curr.copy()

    return prev[m]

# %%
def get_med_dict():
    word_dict = {}
    with open("med_terms.txt",'r') as file:
        lines = file.readlines()
        
    for line in lines:
        first_letter=line[0].lower()
        if first_letter in word_dict:
            word_dict[first_letter].append(line.strip())
        else:
            word_dict[first_letter] = [line.strip()]
    return word_dict

# %%
def get_closest(ocr_word, max_dist=3):
    first = ocr_word[0].lower()
    d = get_med_dict()
    
    med_list = d[first]
    closest = []
    for word in med_list:
        if editDistance(word,ocr_word) <=max_dist:
            closest.append(word)
            
    max_len = min(5,len(closest))
    return closest[:max_len]

# %%
def cleaned_words(text):
    
    ocr_words = re.findall(r'[a-zA-Z]+', txt)
    ocr_words = [word.lower() for word in ocr_words]
    
    spell = Speller()
    corrected = [spell(word) for word in ocr_words]
    english_words = []
    for word in corrected:
        synsets = wordnet.synsets(word)
        if synsets:
            english_words.append(word)
        else:
            english_words.append('')
            
    med_closest = [get_closest(ocr_word) for ocr_word in ocr_words]
    
    key_words={}
    for i,word in enumerate(ocr_words):
        if word in key_words:
            key_words[word].append(english_words[i])
        else:
            key_words[word]=[english_words[i]]
            
        key_words[word].append(med_closest[i])
        
        
    return key_words

# %%
cleaned_words(txt)
# Out:
# {'yeas': ['year', ['yd.', 'Yeast']],
#  'olf': ['', ['OB', 'OBS', 'OCG', 'OCP', 'oma']],
#  'old': ['old', ['OB', 'OBS', 'OCG', 'OCP', 'oma']],
#  'i': ['i',
#   ['ICD', 'ICU', 'ID', 'IFA', 'Ig'],
#   'i',
#   ['ICD', 'ICU', 'ID', 'IFA', 'Ig'],
#   'i',
#   ['ICD', 'ICU', 'ID', 'IFA', 'Ig']],
#  'patent': ['patent', ['pathy', 'Patient']],
#  'paseo': ['', ['pathy']],
#  'vinee': ['vine', []],
#  'a': ['a',
#   ['A-', 'A-T', 'a.c.', 'AAA', 'AAD'],
#   'a',
#   ['A-', 'A-T', 'a.c.', 'AAA', 'AAD']],
#  'reliable': ['reliable', []],
#  'ioral': ['moral', []],
#  'sa': ['sa', ['SAA', 'Salt', 'Scan', 'Ser', 'SHP']],
#  'at': ['at', ['A-', 'A-T', 'a.c.', 'AAA', 'AAD']],
#  'chomapape': ['', []],
#  'with': ['', ['Wt']],
#  'the': ['', ['Td', 'TEE', 'Tic', 'Titre', 'TMR']],
#  'clu': ['club', ['CA', 'CAD', 'Calf', 'caps', 'CBC']],
#  'cowplaints': ['complaints', []],
#  'bn': ['', ['Ba', 'BCC', 'BCG', 'BCM', 'BER']],
#  'ita': ['', ['iatry', 'ICD', 'ICU', 'ID', 'IFA']],
#  'fog': ['fog', ['Fat', 'FCC', 'FDA', 'FFI', 'Food']],
#  'tle': ['', ['Td', 'TEE', 'Tic', 'Titre', 'TMR']],
#  'ipsa': ['psa', ['in', 'itis']],
#  'ae': ['',
#   ['A-', 'A-T', 'a.c.', 'AAA', 'AAD'],
#   '',
#   ['A-', 'A-T', 'a.c.', 'AAA', 'AAD']],
#  'pl': ['', ['p.c.', 'p.o.', 'Palm', 'PAP', 'PAS']],
#  'se': ['se', ['SAA', 'Sense', 'Ser', 'SHP', 'SLV']],
#  'geen': ['been', ['Galen', 'Gene', 'Genu', 'Germ', 'gtt.']],
#  'j': ['j', ['JIP']],
#  'aes': ['', ['A-', 'A-T', 'a.c.', 'AAA', 'AAD']],
#  'sawiduews': ['', []],
#  'ww': ['', ['WBS', 'WF', 'WM', 'WNL', 'Wt']],
#  'onset': ['onset', ['Onset']],
#  'set': ['set', ['SAA', 'Salt', 'Ser', 'SHP', 'SLV']],
#  'cal': ['', ['CA', 'CAD', 'Caecal', 'Calf', 'Calor']],
#  'dusation': ['duration', ['Dilation']],
#  'aday': ['day', ['a.c.', 'Ad-', 'Assay']],
#  'of': ['',
#   ['OB', 'OBS', 'OCG', 'OCP', 'oma'],
#   '',
#   ['OB', 'OBS', 'OCG', 'OCP', 'oma']],
#  'p': ['p', ['p.c.', 'p.o.', 'PAP', 'PAS', 'PAT']],
#  'oav': ['ov', ['OB', 'OBS', 'OCG', 'OCP', 'oma']],
#  'ay': ['', ['A-', 'A-T', 'a.c.', 'AAA', 'AAD']],
#  'qi': ['qi', ['q.2h', 'q.s.']],
#  'vamal': ['', ['Viral', 'Vital']],
#  'vanation': ['vacation', []],
#  'ue': ['',
#   ['UA', 'UBT', 'UL', 'Urea', 'URG'],
#   '',
#   ['UA', 'UBT', 'UL', 'Urea', 'URG']],
#  'no': ['no',
#   ['NCS', 'ND', 'NEP', 'NF', 'NG'],
#   'no',
#   ['NCS', 'ND', 'NEP', 'NF', 'NG'],
#   'no',
#   ['NCS', 'ND', 'NEP', 'NF', 'NG']],
#  'aq': ['', ['A-', 'A-T', 'a.c.', 'AAA', 'AAD']],
#  'oy': ['', ['OB', 'OBS', 'OCG', 'OCP', 'oma']],
#  's': ['s', ['SAA', 'Ser', 'SHP', 'SLV', 'STI']],
#  'rokoving': ['removing', []],
#  'wudieation': ['', []],
#  'n': ['n', ['NCS', 'ND', 'NEP', 'NF', 'NG']],
#  'jupe': ['june', []],
#  'five': ['five', ['Fever', 'Fiber', 'ft.']],
#  'high': ['high', ['Hg', 'His']],
#  'grade': ['grade', ['Graft']],
#  'oneewa': ['', []],
#  't': ['t', ['Td', 'TEE', 'Tic', 'TMR', 'TPN']],
#  'nl': ['', ['NCS', 'ND', 'NEP', 'NF', 'NG']],
#  'ells': ['tells', ['emia']],
#  'vig': ['', ['Vein', 'Void']],
#  'in': ['in', ['ICD', 'ICU', 'ID', 'IFA', 'Ig']],
#  'ee': ['ee', ['Ear', 'EC', 'ECG', 'emia', 'ENT']],
#  'auaation': ['aviation', ['Ablation']],
#  'stne': ['stone', ['Sense', 'Sore', 'Spine']],
#  'd': ['d', ['daw', 'DEA', 'DES', 'DHA', 'Di-']],
#  'days': ['days', ['daw', 'Dys-']],
#  'k': ['k', ['KB', 'KUB']],
#  'weak': ['weak', ['Welt', 'Wheal']],
#  'anoticed': ['noticed', []],
#  'expe': ['', ['emia', 'Eye']],
#  'to': ['', ['Td', 'TEE', 'Tic', 'TMR', 'Tom-']],
#  'onlvonn': ['', []],
#  'kamp': ['', []],
#  'ie': ['ie', ['ICD', 'ICU', 'ID', 'IFA', 'Ig']],
#  'hficourt': ['', []],
#  'itand': ['stand', ['in', 'itis']],
#  'sid': ['', ['SAA', 'Ser', 'SHP', 'Sign', 'Skin']],
#  'nofomieel': ['', []],
#  'wee': ['wee', ['WBS', 'Welt', 'WF', 'WM', 'WNL']],
#  'kc': ['kc', ['KB', 'KUB']]}
